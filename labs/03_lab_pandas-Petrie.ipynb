# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
'''
Part 1: UFO
'''
ufo = pd.read_csv('../data/ufo.csv')   # can also read csvs directly from the web!



# 1. change the column names so that each name has no spaces
#           and all lower case

# 2. Show a bar chart of all shapes reported

# 3. Show a dataframe that only displays the reportings from Utah

# 4. Show a dataframe that only displays the reportings from Texas

# 5. Show a dataframe that only displays the reportings from Utah OR Texas

# 6. Which shape is reported most often?

# 7. Plot number of sightings per day in 2014 (days should be in order!)

# %%
# 1. change the column names so that each name has no spaces
#           and all lower case
ufo.columns
ufo.rename(columns = {'City':'city','Colors Reported': 'ColorsReported', 'Shape Reported': 'ShapeReported', 'State': 'state', 'Time':'time'},inplace = True)
ufo.columns
# Out:
# Index([u'city', u'ColorsReported', u'ShapeReported', u'state', u'time'], dtype='object')

# %%
# 2. Show a bar chart of all shapes reported
ufo.ShapeReported.value_counts().plot(kind='bar', title='Shapes Reported')
plt.xlabel('Shapes Reported')
plt.ylabel('Count')

# %%
# 3. Show a dataframe that only displays the reportings from Utah
ufo[ufo.state == "UT"]
# Out:
#                             city ColorsReported ShapeReported state  \
# 29                  Ft. Duschene            NaN          DISK    UT
# 164                        Provo           BLUE          DISK    UT
# 170               Salt Lake City            NaN           NaN    UT
# 356               Salt Lake City            NaN        CIRCLE    UT
# 433              Salt  Lake City            NaN          DISK    UT
# 504                      no data            NaN          DISK    UT
# 590               Salt Lake City            NaN          DISK    UT
# 657                       Alpine            NaN          DISK    UT
# 700                     Wendover            NaN          DISK    UT
# 816               Salt Lake City            NaN          DISK    UT
# 936            Crescent Junction            NaN          DISK    UT
# 1433              Salt Lake City            NaN          DISK    UT
# 1584                       Provo         YELLOW        SPHERE    UT
# 1639              Salt Lake City            NaN         LIGHT    UT
# 1665              Salt Lake City            NaN        CIRCLE    UT
# 1849              Salt Lake City            NaN        CIRCLE    UT
# 1997                       Provo            NaN          DISK    UT
# 2232                       Provo            NaN          DISK    UT
# 2262                   Salt Lake            NaN          OVAL    UT
# 2264                       Provo            NaN          DISK    UT
# 2547                 Green River            NaN          DISK    UT
# 2548                 Green River            RED          DISK    UT
# 2748                       Delta            NaN          DISK    UT
# 2797                    Eastland            NaN        SPHERE    UT
# 2967              Salt Lake City            NaN         LIGHT    UT
# 3029                Brigham City            NaN          DISK    UT
# 3185                     Midvale            NaN       CHEVRON    UT
# 3396                  St. George            RED         LIGHT    UT
# 3513                  Cedar City            NaN      TRIANGLE    UT
# 3907                       Provo            NaN          DISK    UT
# ...                          ...            ...           ...   ...
# 76538               Taylorsville            NaN         LIGHT    UT
# 76594                  Park City            NaN         OTHER    UT
# 76639                       Moab            RED         LIGHT    UT
# 76647                       Mona            NaN      FIREBALL    UT
# 76880             Salt Lake City      RED GREEN       DIAMOND    UT
# 76883                      Provo            NaN       VARIOUS    UT
# 76944                 Washington            NaN     RECTANGLE    UT
# 77043                       Eden            NaN         LIGHT    UT
# 77350                      Ogden            NaN       VARIOUS    UT
# 77409                      Salem         ORANGE        SPHERE    UT
# 77592                  Riverdale            NaN        SPHERE    UT
# 77991             Salt Lake City            NaN         OTHER    UT
# 78115                     Murray            NaN          OVAL    UT
# 78246                  Kaysville            NaN         LIGHT    UT
# 78467         Duck Creek Village            NaN        SPHERE    UT
# 78628                       Lehi            NaN         LIGHT    UT
# 78697             Salt Lake City            NaN     FORMATION    UT
# 79127             Salt Lake City         ORANGE      FIREBALL    UT
# 79283                    Midvale            NaN          DISK    UT
# 79625                     Salina      RED GREEN          OVAL    UT
# 79638                 West Point            NaN         FLASH    UT
# 79825             Salt Lake City            RED        CIRCLE    UT
# 79964                West Valley           BLUE           NaN    UT
# 80012             Salt Lake City            NaN      TRIANGLE    UT
# 80045                     Kearns            NaN         LIGHT    UT
# 80101  Canyonlands National Park            NaN           NaN    UT
# 80137                       Lehi            NaN           NaN    UT
# 80254                     Murray            RED       VARIOUS    UT
# 80344             Salt Lake City            NaN         LIGHT    UT
# 80486                      Minot            NaN        CIRCLE    UT
#
#                    time
# 29      6/30/1944 10:00
# 164     7/10/1951 23:30
# 170       1/1/1952 0:00
# 356       6/5/1956 0:00
# 433     7/15/1957 22:00
# 504     7/11/1958 23:00
# 590       6/1/1960 0:00
# 657       6/1/1961 0:00
# 700       3/3/1962 3:00
# 816     6/30/1963 13:00
# 936      9/15/1964 2:00
# 1433    6/15/1967 20:30
# 1584    5/15/1968 21:00
# 1639     6/20/1968 7:00
# 1665     7/1/1968 20:45
# 1849    7/10/1969 12:00
# 1997    7/15/1970 11:00
# 2232    6/16/1972 18:30
# 2262     7/1/1972 12:00
# 2264     7/1/1972 19:00
# 2547    10/30/1973 4:00
# 2548    10/30/1973 4:00
# 2748    8/20/1974 23:45
# 2797   10/27/1974 21:00
# 2967      7/1/1975 3:00
# 3029     8/15/1975 0:00
# 3185      6/1/1976 1:00
# 3396   10/21/1976 21:00
# 3513    6/15/1977 13:00
# 3907    8/15/1978 18:00
# ...                 ...
# 76538    3/17/2014 6:57
# 76594   3/20/2014 22:30
# 76639    3/24/2014 2:00
# 76647   3/24/2014 21:30
# 76880    4/6/2014 22:45
# 76883     4/7/2014 0:00
# 76944   4/10/2014 20:10
# 77043   4/14/2014 22:00
# 77350   4/30/2014 21:00
# 77409    5/2/2014 22:00
# 77592   5/13/2014 16:00
# 77991    6/3/2014 17:35
# 78115    6/9/2014 19:30
# 78246   6/15/2014 22:15
# 78467   6/22/2014 23:03
# 78628    6/29/2014 4:20
# 78697    7/2/2014 23:30
# 79127    7/7/2014 22:40
# 79283   7/13/2014 13:45
# 79625   7/29/2014 22:35
# 79638   7/30/2014 22:30
# 79825    8/8/2014 19:30
# 79964    8/15/2014 6:00
# 80012   8/16/2014 21:45
# 80045   8/17/2014 22:57
# 80101    8/20/2014 3:00
# 80137   8/21/2014 21:50
# 80254   8/25/2014 10:00
# 80344   8/28/2014 19:00
# 80486     9/3/2014 0:00
#
# [823 rows x 5 columns]

# %%
# 4. Show a dataframe that only displays the reportings from Texas
ufo[ufo.state == "TX"]
# Out:
#                           city ColorsReported ShapeReported state  \
# 37                      Dallas            NaN        SPHERE    TX
# 43                       Alice            NaN          DISK    TX
# 49                      Conroe            NaN         OTHER    TX
# 92                      Borger            NaN          DISK    TX
# 114                       Post            NaN          DISK    TX
# 115                 San Marcos            NaN      CYLINDER    TX
# 116               Lackland AFB            NaN         LIGHT    TX
# 132                 Fort Worth            NaN          DISK    TX
# 134                  Galveston            NaN        SPHERE    TX
# 174                 Greenville         ORANGE      TRIANGLE    TX
# 189                      Pecos            NaN          DISK    TX
# 201                  Arlington            NaN          DISK    TX
# 213          Smithson's Valley            NaN         CIGAR    TX
# 223                   Oklahoma            NaN         CIGAR    TX
# 235                 Fort Worth            NaN        SPHERE    TX
# 237                  Galveston            NaN         CIGAR    TX
# 252               Mauriceville            NaN          DISK    TX
# 257    Lackland Air Force Base            NaN          DISK    TX
# 267                    Houston            NaN          DISK    TX
# 280              Ellington AFB            NaN          DISK    TX
# 283                    Thrifty            NaN        CIRCLE    TX
# 304                   Beaumont            RED          DISK    TX
# 307                     Blanco            NaN         OTHER    TX
# 310                     Thelma            NaN          DISK    TX
# 330                    Lubbock            NaN         CIGAR    TX
# 331                      Dumas            NaN         LIGHT    TX
# 340                 Eagle Pass            NaN         CIGAR    TX
# 359                      Edroy            NaN           NaN    TX
# 373                    Houston            NaN      TRIANGLE    TX
# 387                       Edna            NaN        CIRCLE    TX
# ...                        ...            ...           ...   ...
# 79676                   Austin            RED           NaN    TX
# 79697               Fort Worth           BLUE        CIRCLE    TX
# 79708                 Von Ormy            NaN         LIGHT    TX
# 79746                 Cleburne            NaN         LIGHT    TX
# 79763                  Cypress            NaN      FIREBALL    TX
# 79774              Port Neches            NaN         LIGHT    TX
# 79790                 Amarillo            NaN      TRIANGLE    TX
# 79803                    Allen           BLUE     RECTANGLE    TX
# 79848                    Allen            NaN         LIGHT    TX
# 79874               San Angelo            NaN         LIGHT    TX
# 79891                     Katy            NaN      FIREBALL    TX
# 79919                 McKinney      RED GREEN     RECTANGLE    TX
# 79921                  Cypress            NaN      TRIANGLE    TX
# 79933                  Comfort            NaN         LIGHT    TX
# 79938                 Pearland            NaN          CONE    TX
# 79965                   Austin            NaN        CIRCLE    TX
# 79969                   Austin            RED        CIRCLE    TX
# 79986                  Houston         YELLOW        CIRCLE    TX
# 80038                   Borger            NaN         LIGHT    TX
# 80075               Round Rock         ORANGE         LIGHT    TX
# 80113                   Menard            RED         LIGHT    TX
# 80134                   Morton            NaN        SPHERE    TX
# 80141              Port Neches     GREEN BLUE         LIGHT    TX
# 80240            New Braunfels            RED         LIGHT    TX
# 80241               Atascocita            NaN        CIRCLE    TX
# 80287               Lago Vista            NaN      TRIANGLE    TX
# 80350                  Houston            NaN      TRIANGLE    TX
# 80414                  Eustace            NaN         LIGHT    TX
# 80476               Fort Worth            NaN         OTHER    TX
# 80534                 Burleson            NaN         LIGHT    TX
#
#                    time
# 37      7/15/1945 14:00
# 43      3/15/1946 15:30
# 49      1/10/1947 20:00
# 92      6/15/1948 16:00
# 114     9/15/1949 21:00
# 115    10/10/1949 20:30
# 116    10/10/1949 21:00
# 132     6/15/1950 20:00
# 134     6/20/1950 17:00
# 174     4/15/1952 16:00
# 189      6/30/1952 3:00
# 201      7/7/1952 13:00
# 213     8/15/1952 17:00
# 223      1/1/1953 14:00
# 235     6/15/1953 13:00
# 237      6/17/1953 7:30
# 252    10/15/1953 14:00
# 257     11/25/1953 4:25
# 267       6/1/1954 0:00
# 280     6/15/1954 16:30
# 283      6/25/1954 3:30
# 304      9/9/1954 12:30
# 307    10/15/1954 16:30
# 310     11/14/1954 1:00
# 330     6/30/1955 13:00
# 331     6/30/1955 21:00
# 340      8/15/1955 0:01
# 359      6/15/1956 1:00
# 373     6/30/1956 18:30
# 387    10/10/1956 21:00
# ...                 ...
# 79676    8/1/2014 20:55
# 79697     8/2/2014 5:58
# 79708    8/2/2014 21:20
# 79746    8/3/2014 20:15
# 79763     8/4/2014 0:00
# 79774     8/5/2014 0:00
# 79790    8/5/2014 23:00
# 79803    8/6/2014 22:30
# 79848     8/9/2014 4:00
# 79874    8/9/2014 23:30
# 79891   8/10/2014 23:00
# 79919    8/13/2014 2:05
# 79921    8/13/2014 8:45
# 79933   8/13/2014 22:00
# 79938    8/14/2014 7:30
# 79965    8/15/2014 6:45
# 79969   8/15/2014 18:45
# 79986   8/15/2014 23:30
# 80038   8/17/2014 21:15
# 80075    8/19/2014 1:32
# 80113   8/20/2014 21:40
# 80134   8/21/2014 20:15
# 80141   8/21/2014 23:00
# 80240   8/24/2014 21:05
# 80241   8/24/2014 21:15
# 80287    8/26/2014 3:35
# 80350   8/28/2014 19:55
# 80414   8/30/2014 23:00
# 80476    9/2/2014 16:05
# 80534    9/4/2014 22:30
#
# [4186 rows x 5 columns]

# %%
# 5. Show a dataframe that only displays the reportings from Utah OR Texas
# look this up :P
ufo[(ufo.state == 'UT')| (ufo.state == 'TX')]
# Out:
#                             city ColorsReported ShapeReported state  \
# 29                  Ft. Duschene            NaN          DISK    UT
# 37                        Dallas            NaN        SPHERE    TX
# 43                         Alice            NaN          DISK    TX
# 49                        Conroe            NaN         OTHER    TX
# 92                        Borger            NaN          DISK    TX
# 114                         Post            NaN          DISK    TX
# 115                   San Marcos            NaN      CYLINDER    TX
# 116                 Lackland AFB            NaN         LIGHT    TX
# 132                   Fort Worth            NaN          DISK    TX
# 134                    Galveston            NaN        SPHERE    TX
# 164                        Provo           BLUE          DISK    UT
# 170               Salt Lake City            NaN           NaN    UT
# 174                   Greenville         ORANGE      TRIANGLE    TX
# 189                        Pecos            NaN          DISK    TX
# 201                    Arlington            NaN          DISK    TX
# 213            Smithson's Valley            NaN         CIGAR    TX
# 223                     Oklahoma            NaN         CIGAR    TX
# 235                   Fort Worth            NaN        SPHERE    TX
# 237                    Galveston            NaN         CIGAR    TX
# 252                 Mauriceville            NaN          DISK    TX
# 257      Lackland Air Force Base            NaN          DISK    TX
# 267                      Houston            NaN          DISK    TX
# 280                Ellington AFB            NaN          DISK    TX
# 283                      Thrifty            NaN        CIRCLE    TX
# 304                     Beaumont            RED          DISK    TX
# 307                       Blanco            NaN         OTHER    TX
# 310                       Thelma            NaN          DISK    TX
# 330                      Lubbock            NaN         CIGAR    TX
# 331                        Dumas            NaN         LIGHT    TX
# 340                   Eagle Pass            NaN         CIGAR    TX
# ...                          ...            ...           ...   ...
# 79848                      Allen            NaN         LIGHT    TX
# 79874                 San Angelo            NaN         LIGHT    TX
# 79891                       Katy            NaN      FIREBALL    TX
# 79919                   McKinney      RED GREEN     RECTANGLE    TX
# 79921                    Cypress            NaN      TRIANGLE    TX
# 79933                    Comfort            NaN         LIGHT    TX
# 79938                   Pearland            NaN          CONE    TX
# 79964                West Valley           BLUE           NaN    UT
# 79965                     Austin            NaN        CIRCLE    TX
# 79969                     Austin            RED        CIRCLE    TX
# 79986                    Houston         YELLOW        CIRCLE    TX
# 80012             Salt Lake City            NaN      TRIANGLE    UT
# 80038                     Borger            NaN         LIGHT    TX
# 80045                     Kearns            NaN         LIGHT    UT
# 80075                 Round Rock         ORANGE         LIGHT    TX
# 80101  Canyonlands National Park            NaN           NaN    UT
# 80113                     Menard            RED         LIGHT    TX
# 80134                     Morton            NaN        SPHERE    TX
# 80137                       Lehi            NaN           NaN    UT
# 80141                Port Neches     GREEN BLUE         LIGHT    TX
# 80240              New Braunfels            RED         LIGHT    TX
# 80241                 Atascocita            NaN        CIRCLE    TX
# 80254                     Murray            RED       VARIOUS    UT
# 80287                 Lago Vista            NaN      TRIANGLE    TX
# 80344             Salt Lake City            NaN         LIGHT    UT
# 80350                    Houston            NaN      TRIANGLE    TX
# 80414                    Eustace            NaN         LIGHT    TX
# 80476                 Fort Worth            NaN         OTHER    TX
# 80486                      Minot            NaN        CIRCLE    UT
# 80534                   Burleson            NaN         LIGHT    TX
#
#                    time
# 29      6/30/1944 10:00
# 37      7/15/1945 14:00
# 43      3/15/1946 15:30
# 49      1/10/1947 20:00
# 92      6/15/1948 16:00
# 114     9/15/1949 21:00
# 115    10/10/1949 20:30
# 116    10/10/1949 21:00
# 132     6/15/1950 20:00
# 134     6/20/1950 17:00
# 164     7/10/1951 23:30
# 170       1/1/1952 0:00
# 174     4/15/1952 16:00
# 189      6/30/1952 3:00
# 201      7/7/1952 13:00
# 213     8/15/1952 17:00
# 223      1/1/1953 14:00
# 235     6/15/1953 13:00
# 237      6/17/1953 7:30
# 252    10/15/1953 14:00
# 257     11/25/1953 4:25
# 267       6/1/1954 0:00
# 280     6/15/1954 16:30
# 283      6/25/1954 3:30
# 304      9/9/1954 12:30
# 307    10/15/1954 16:30
# 310     11/14/1954 1:00
# 330     6/30/1955 13:00
# 331     6/30/1955 21:00
# 340      8/15/1955 0:01
# ...                 ...
# 79848     8/9/2014 4:00
# 79874    8/9/2014 23:30
# 79891   8/10/2014 23:00
# 79919    8/13/2014 2:05
# 79921    8/13/2014 8:45
# 79933   8/13/2014 22:00
# 79938    8/14/2014 7:30
# 79964    8/15/2014 6:00
# 79965    8/15/2014 6:45
# 79969   8/15/2014 18:45
# 79986   8/15/2014 23:30
# 80012   8/16/2014 21:45
# 80038   8/17/2014 21:15
# 80045   8/17/2014 22:57
# 80075    8/19/2014 1:32
# 80101    8/20/2014 3:00
# 80113   8/20/2014 21:40
# 80134   8/21/2014 20:15
# 80137   8/21/2014 21:50
# 80141   8/21/2014 23:00
# 80240   8/24/2014 21:05
# 80241   8/24/2014 21:15
# 80254   8/25/2014 10:00
# 80287    8/26/2014 3:35
# 80344   8/28/2014 19:00
# 80350   8/28/2014 19:55
# 80414   8/30/2014 23:00
# 80476    9/2/2014 16:05
# 80486     9/3/2014 0:00
# 80534    9/4/2014 22:30
#
# [5009 rows x 5 columns]

# %%
# 6. Which shape is reported most often?
ufo['ShapeReported'].tail(1)
# Out:
# 80542    LIGHT
# Name: ShapeReported, dtype: object

# %%
# 7. Plot number of sightings per day in 2014 (days should be in order!)
import datetime

# %%
current_date = '%m/%d/%Y %H:%M'
datetime.datetime.strptime('9/4/2014 22:30', current_date).strftime('%Y')
# Out:
# '2014'

# %%
ufo['year'] = [datetime.datetime.strptime(x, current_date).strftime('%Y') for x in ufo['time']]

# %%
ufo['day'] = [datetime.datetime.strptime(x, current_date).strftime('%d') for x in ufo['time']]

# %%
ufo['day']
# Out:
# 0        01
# 1        30
# 2        15
# 3        01
# 4        18
# 5        15
# 6        15
# 7        15
# 8        15
# 9        15
# 10       15
# 11       01
# 12       30
# 13       07
# 14       01
# 15       02
# 16       25
# 17       01
# 18       15
# 19       30
# 20       01
# 21       15
# 22       15
# 23       15
# 24       01
# 25       01
# 26       01
# 27       02
# 28       01
# 29       30
#          ..
# 80513    04
# 80514    04
# 80515    04
# 80516    04
# 80517    04
# 80518    04
# 80519    04
# 80520    04
# 80521    04
# 80522    04
# 80523    04
# 80524    04
# 80525    04
# 80526    04
# 80527    04
# 80528    04
# 80529    04
# 80530    04
# 80531    04
# 80532    04
# 80533    04
# 80534    04
# 80535    04
# 80536    04
# 80537    04
# 80538    04
# 80539    05
# 80540    05
# 80541    05
# 80542    05
# Name: day, dtype: object

# %%
ufo[ufo.year == '2014'].groupby('day')['day'].count().plot()

# %%
'''
Part 2: IRIS
'''

iris = pd.read_csv('../data/iris.csv')   # can also read csvs directly from the web!

# 1. Show the mean petal length by flower species

# 2. Show the mean sepal width by flower species

# 3. Use the groupby to show both #1 and #2 in one dataframe

# 4. Create a scatter plot plotting petal length against petal width
#    Use the color_flowers function to 

# 5. Show flowers with sepal length over 5 and petal length under 1.5

# 6. Show setosa flowers with petal width of exactly 0.2

# 7. Write a function to predict the species for each observation

def classify_iris(data):
    if False:
        return 'Iris-setosa'
    elif False:
        return 'Iris-versicolor'
    else:
        return 'Iris-virginica'

# example use: 
# classify_iris([0,3,2.1,3.2]) == 'Iris-virginica'
# assume the order is the same as the dataframe, so:
# [sepal_length', 'sepal_width', 'petal_length', 'petal_width']


# make predictions and store as preds
preds = iris.drop('species', axis=1).apply(classify_iris, axis = 1)


preds


# test your function: compute accuracy of your prediction
(preds == iris['species']).sum() / float(iris.shape[0])
# Out:
# 0.33333333333333331

# %%
# 1. Show the mean petal length by flower species
iris.describe()
iris.groupby('species').petal_length.mean()
# Out:
# species
# Iris-setosa        1.464
# Iris-versicolor    4.260
# Iris-virginica     5.552
# Name: petal_length, dtype: float64

# %%
# 2. Show the mean sepal width by flower species
iris.groupby('species').sepal_length.mean()
# Out:
# species
# Iris-setosa        5.006
# Iris-versicolor    5.936
# Iris-virginica     6.588
# Name: sepal_length, dtype: float64

# %%
 3. #Use the groupby to show both #1 and #2 in one dataframe
iris.groupby('species')['petal_length', 'sepal_length'].mean()
# Out:
#                  petal_length  sepal_length
# species
# Iris-setosa             1.464         5.006
# Iris-versicolor         4.260         5.936
# Iris-virginica          5.552         6.588

# %%
# 4. Create a scatter plot plotting petal length against petal width
iris.plot(x='petal_length', y='petal_width', kind='scatter')

# %%
# 5. Show flowers with sepal length over 5 and petal length under 1.5
iris[(iris.sepal_length > 5) & (iris.petal_length < 1.5)]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width      species
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 14           5.8          4.0           1.2          0.2  Iris-setosa
# 16           5.4          3.9           1.3          0.4  Iris-setosa
# 17           5.1          3.5           1.4          0.3  Iris-setosa
# 28           5.2          3.4           1.4          0.2  Iris-setosa
# 33           5.5          4.2           1.4          0.2  Iris-setosa
# 36           5.5          3.5           1.3          0.2  Iris-setosa

# %%
# 6. Show setosa flowers with petal width of exactly 0.2
iris.groupby('species')['petal_width'][iris.petal_width == 0.2]
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-214-dc75752e372b> in <module>()
#       1 # 6. Show setosa flowers with petal width of exactly 0.2
# ----> 2 iris.groupby('species')['petal_width'][iris.petal_width == 0.2]
#
# /Users/anastasia.petrie/anaconda/lib/python2.7/site-packages/pandas/core/groupby.pyc in __getitem__(self, key)
#     560
#     561     def __getitem__(self, key):
# --> 562         raise NotImplementedError('Not implemented: %s' % key)
#     563
#     564     plot = property(GroupByPlot)
#
# NotImplementedError: Not implemented: 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5      False
# 6      False
# 7       True
# 8       True
# 9      False
# 10      True
# 11      True
# 12     False
# 13     False
# 14      True
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20      True
# 21     False
# 22      True
# 23     False
# 24      True
# 25      True
# 26     False
# 27      True
# 28      True
# 29      True
#        ...
# 120    False
# 121    False
# 122    False
# 123    False
# 124    False
# 125    False
# 126    False
# 127    False
# 128    False
# 129    False
# 130    False
# 131    False
# 132    False
# 133    False
# 134    False
# 135    False
# 136    False
# 137    False
# 138    False
# 139    False
# 140    False
# 141    False
# 142    False
# 143    False
# 144    False
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Name: petal_width, dtype: bool

# %%
# 7. Write a function to predict the species for each observation

# %%
'''
Part 3: FIFA GOALS
'''


goals = pd.read_csv('../data/fifa_goals.csv')


# 1. Some elements in the minute column have a  '+', remove it and cast each element as an int!

# 2. Show goals scored in the first 5 minutes of a game

# 3. Show goals scored after the regulation 90 minutes is over

# 4. Show the top scoring players

# 5. Show a histogram (distribution) of minutes with 20 bins

# 6. Show a histogram of the number of goals scored by players

# %%
goals.describe()
goals.columns
goals.head()
goals
# Out:
#       game_id minute              player  team1score  team2score
# 0           1     18            Schiavio           1           0
# 1           1     20                Orsi           2           0
# 2           1     29            Schiavio           3           0
# 3           1     57             Donelli           3           1
# 4           1     63             Ferrari           4           1
# 5           1     64            Schiavio           5           1
# 6           1     69                Orsi           6           1
# 7           1    90+              Meazza           7           1
# 8           2     18             Nicolas           0           1
# 9           2     44            Sindelar           1           1
# 10          2     93              Schall           2           1
# 11          2    109              BiÄan           3           1
# 12          2    118       Verriest [p.]           3           2
# 13          3     25           Kobierski           1           0
# 14          3     29            Voorhoof           1           1
# 15          3     43            Voorhoof           1           2
# 16          3     49            Siffling           2           2
# 17          3     66               Conen           3           2
# 18          3     70               Conen           4           2
# 19          3     87               Conen           5           2
# 20          4     11               Dobai           0           1
# 21          4     50                PuÄ           1           1
# 22          4     67            NejedlÃ½           2           1
# 23          5      7            Kielholz           1           0
# 24          5     19                Smit           1           1
# 25          5     43            Kielholz           2           1
# 26          5     69            Abegglen           3           1
# 27          5     84               Vente           3           2
# 28          6      4               Belis           0           1
# 29          6      9            Jonasson           1           1
# ...       ...    ...                 ...         ...         ...
# 2177      831      4           Hidegkuti           1           0
# 2178      831      7              Kocsis           2           0
# 2179      831     18  Djalma Santos [p.]           2           1
# 2180      831     60         Lantos [p.]           3           1
# 2181      831     65             Julinho           3           2
# 2182      831     88              Kocsis           4           2
# 2183      832      9       Horvat [o.g.]           1           0
# 2184      832     85                Rahn           2           0
# 2185      833     12              Czibor           1           0
# 2186      833     47           Hidegkuti           2           0
# 2187      833     75             Hohberg           2           1
# 2188      833     86             Hohberg           2           2
# 2189      833    111              Kocsis           3           2
# 2190      833    116              Kocsis           4           2
# 2191      834     31            SchÃ¤fer           1           0
# 2192      834     47             Morlock           2           0
# 2193      834     51              Probst           2           1
# 2194      834     54      F. Walter [p.]           3           1
# 2195      834     61           O. Walter           4           1
# 2196      834     64      F. Walter [p.]           5           1
# 2197      834     89           O. Walter           6           1
# 2198      835     16      Stojaspal [p.]           1           0
# 2199      835     22             Hohberg           1           1
# 2200      835     59         Cruz [o.g.]           2           1
# 2201      835     79              Ocwirk           3           1
# 2202      836      6             PuskÃ¡s           0           1
# 2203      836      8              Czibor           0           2
# 2204      836     10             Morlock           1           2
# 2205      836     18                Rahn           2           2
# 2206      836     84                Rahn           3           2
#
# [2207 rows x 5 columns]

# %%
goals.isnull().sum()
# Out:
# game_id       0
# minute        0
# player        0
# team1score    0
# team2score    0
# dtype: int64

# %%
# 1. Some elements in the minute column have a  '+', remove it and cast each element as an int!
goals['minute'] = goals['minute'].map(lambda x: x.replace("+",''))
goals['minute'] = goals['minute'].convert_objects(convert_numeric=True)
# Out:
# /Users/anastasia.petrie/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   app.launch_new_instance()

# %%
# 2. Show goals scored in the first 5 minutes of a game
goals[goals.minute < 6]
# Out:
#       game_id  minute          player  team1score  team2score
# 28          6       4           Belis           0           1
# 62         16       1          Lehner           1           0
# 73         19       3        Corbatta           0           1
# 90         23       4          Bozsik           1           0
# 103        27       4       McParland           0           1
# 107        28       3         AgÃ¼ero           1           0
# 112        29       5        Fontaine           0           1
# 148        40       3           VavÃ¡           1           0
# 173        50       2           VavÃ¡           1           0
# 189        52       3        Liedholm           0           1
# 200        57       4         Nyilasi           1           0
# 221        60       1          Robson           1           0
# 297        90       4          Boniek           1           0
# 320        99       5           Rossi           1           0
# 357       111       1   JosÃ© Augusto           1           0
# 369       115       2            Bene           1           0
# 404       130       1  Park Seung-jin           0           1
# 412       131       5       Chislenko           1           0
# 442       204       1           DeÅu           1           0
# 447       206       3        Subiabre           1           0
# 488       217       4    VujadinoviÄ           0           1
# 509       223       2       Yakovenko           1           0
# 510       223       4       Alejnikov           2           0
# 522       229       4       Alzamendi           1           0
# 531       234       2      EsterhÃ¡zy           1           0
# 534       237       3          Flores           1           0
# 536       238       2     ButragueÃ±o           0           1
# 563       246       3         Valdano           1           0
# 635       272       2        Ferraris           1           0
# 638       273       1        Veinante           1           0
# ...       ...     ...             ...         ...         ...
# 1400      547       4           Rusol           0           1
# 1408      549       4           Klose           0           1
# 1440      560       2            Srna           1           0
# 1450      565       4        Podolski           1           0
# 1458      571       5         Ronaldo           1           0
# 1505      591       3        PetrÃ¡Å¡           0           1
# 1580      617       4         Gerrard           1           0
# 1679      662       5  Prince Boateng           0           1
# 1703      671       3         MÃ¼ller           0           1
# 1729      680       4         Facundo           1           0
# 1758      692       1          Albert           1           0
# 1778      698       1            Mora           1           0
# 1781      699       1          MaÅ¡ek           0           1
# 1856      729       5   Neeskens [p.]           0           1
# 1903      746       2   Neeskens [p.]           0           1
# 1947      762       4       OâBrien           1           0
# 1965      770       4        Nomvethe           1           0
# 1973      773       5         Delgado           0           1
# 2002      785       4           RaÃºl           0           1
# 2031      793       3       Olisadebe           1           0
# 2032      793       5   KryszaÅowicz           2           0
# 2037      796       5       Ferdinand           0           1
# 2060      809       1  Hakan ÅÃ¼kÃ¼r           1           0
# 2088      817       2            Suat           0           1
# 2093      818       4           Anoul           0           1
# 2110      821       2       Stojaspal           1           0
# 2111      821       4          Probst           2           0
# 2120      823       3          Kocsis           1           0
# 2159      829       5          Borges           1           0
# 2177      831       4       Hidegkuti           1           0
#
# [82 rows x 5 columns]

# %%
# 3. Show goals scored after the regulation 90 minutes is over
goals[goals.minute == 90]
# Out:
#       game_id  minute              player  team1score  team2score
# 7           1      90              Meazza           7           1
# 195        52      90               PelÃ©           5           2
# 250        71      90             Moscoso           4           1
# 360       111      90              Torres           3           1
# 619       267      90             VÃ¶ller           0           2
# 684       282      90         ZsengellÃ©r           2           0
# 809       312      90         Su Jung-won           2           2
# 844       325      90            Valencia           2           1
# 866       334      90           Borimirov           4           0
# 868       335      90              Lozano           0           2
# 895       345      90             Sirakov           0           2
# 897       346      90            Amokachi           0           2
# 902       347      90              Albert           3           2
# 958       366      90             Polster           1           1
# 962       369      90               Henry           3           0
# 988       381      90             VastiÄ           1           1
# 1029      396      90         Herzog [p.]           2           1
# 1042      400      90       Bartlett [p.]           2           2
# 1053      402      90                Kiko           6           1
# 1057      403      90          HernÃ¡ndez           2           2
# 1088      416      90              Davids           2           1
# 1115      426      90               Petit           3           0
# 1127      431      90             LuhovÃ½           1           5
# 1176      453      90             RincÃ³n           1           1
# 1181      454      90         ProsineÄki           4           1
# 1191      459      90             Fonseca           0           1
# 1354      525      90              Aloisi           3           1
# 1371      532      90              JaÃ¯di           2           2
# 1372      533      90            Neuville           1           0
# 1375      534      90            Kaviedes           3           0
# 1377      535      90             Gerrard           2           0
# 1395      544      90                Fred           2           0
# 1407      548      90         Torres [p.]           3           1
# 1417      551      90             Larsson           2           2
# 1457      569      90          Totti [p.]           1           0
# 1464      572      90              Zidane           1           3
# 1527      598      90               Grahn           1           0
# 1563      610      90        Schnellinger           1           1
# 1594      624      90                Reid           1           1
# 1602      629      90         Ã. Pereira           0           3
# 1653      650      90             Donovan           1           0
# 1662      653      90        Quagliarella           3           2
# 1693      665      90         Vittek [p.]           2           1
# 1712      673      90          M. Pereira           2           3
# 1757      691      90              PeirÃ³           1           0
# 1784      699      90  H. HernÃ¡ndez [p.]           3           1
# 1804      707      90               Rojas           1           0
# 1877      734      90             Cruijff           4           0
# 1919      750      90           Schneider           8           0
# 1924      752      90        Fortune [p.]           2           2
# 1953      763      90        Robbie Keane           1           1
# 2044      798      90   Robbie Keane [p.]           1           1
# 2064      809      90      Song Jong-gook           3           2
# 2158      828      90              Fatton           4           1

# %%
# 4. Show the top scoring players
goals['player'].value_counts().head(5)
# Out:
# MÃ¼ller     20
# Klose       14
# Ronaldo     14
# Fontaine    13
# PelÃ©       12
# Name: player, dtype: int64

# %%
# 5. Show a histogram (distribution) of minutes with 20 bins
goals.minute.hist(bins = 20)

# %%
#6. Show a histogram of the number of goals scored by players
player_goals = goals.groupby('player').player.count()

# %%
type(player_goals)
# Out:
# pandas.core.series.Series

# %%
player_goals
# Out:
# player
# A. Ivanov                      2
# A. KÃ¶rner                     2
# A. Svensson                    1
# A. TÃ³th [p.]                  1
# Abbadie                        2
# Abdelghani [p.]                1
# Abegglen                       4
# Abramczik                      1
# Aceros                         1
# Adelardo                       1
# Ademir                         9
# Adriano                        2
# Agger [o.g.]                   1
# Aghahowa                       1
# Agoos [o.g.]                   1
# AgÃ¼ero                        2
# Ahn Jung-hwan                  2
# Ahn Jung-hwan [Golden Goal]    1
# Ahumada                        1
# Al-Buloushi                    1
# Al-Dakhil                      1
# Al-Ghesheyan                   1
# Al-Jaber                       1
# Al-Jaber [p.]                  2
# Al-Owairan                     1
# Al-Qahtani                     1
# Al-Thunayan [p.]               1
# Albert                         6
# Alcaraz                        1
# Aldridge                       1
#                               ..
# Zenden                         1
# Zhechev                        1
# Zico                           4
# Zico [p.]                      1
# Zidane                         4
# Zidane [p.]                    2
# ZikÃ¡n                         4
# Zinha                          1
# Zischek                        1
# Zito                           1
# Zizinho                        2
# Zombori                        1
# ZsengellÃ©r                    5
# Zubizarreta [o.g.]             1
# Zuluaga [p.]                   1
# ZumelzÃº                       2
# Zygmantovich                   1
# ZÃ© Roberto                    1
# Ã. Pereira                    1
# Ãder                          2
# Ãzil                          1
# Ãmit Davala                   2
# Ä°lhan                         2
# Ä°lhan [Golden Goal]           1
# Å tibrÃ¡nyi                    1
# Å uker                         5
# Å uker [p.]                    1
# Å urjak                        2
# Å½eljko Äajkovski             2
# Å½igiÄ                        1
# Name: player, dtype: int64

# %%
player_goals.hist()
plt.xlabel('Number of Goals')
plt.ylabel('Number of Players')
